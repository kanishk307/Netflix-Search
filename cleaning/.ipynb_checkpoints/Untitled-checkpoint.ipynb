# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../dataset/netflix_titles.csv")

# %%
df.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
pd.concat([df.iloc[[]], df['country'].str.split(', ', expand=True)], axis=1)
# Out:
#          show_id     type    title director  \
# 0            NaN      NaN      NaN      NaN
# 1            NaN      NaN      NaN      NaN
# 2            NaN      NaN      NaN      NaN
# 3            NaN      NaN      NaN      NaN
# 4            NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...
# 6229         NaN      NaN      NaN      NaN
# 6230         NaN      NaN      NaN      NaN
# 6231         NaN      NaN      NaN      NaN
# 6232         NaN      NaN      NaN      NaN
# 6233  70153404.0  TV Show  Friends      NaN
#
#                                                    cast        country  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...

# %%
# Out:
# <bound method NDFrame.head of                    0       1             2       3     4     5     6     7  \
# 0      United States   India   South Korea   China  None  None  None  None
# 1     United Kingdom    None          None    None  None  None  None  None
# 2      United States    None          None    None  None  None  None  None
# 3      United States    None          None    None  None  None  None  None
# 4      United States    None          None    None  None  None  None  None
# ...              ...     ...           ...     ...   ...   ...   ...   ...
# 6229   United States    None          None    None  None  None  None  None
# 6230   United States    None          None    None  None  None  None  None
# 6231             NaN     NaN           NaN     NaN   NaN   NaN   NaN   NaN
# 6232  United Kingdom    None          None    None  None  None  None  None
# 6233   United States    None          None    None  None  None  None  None
#
#          8     9    10    11
# ...
